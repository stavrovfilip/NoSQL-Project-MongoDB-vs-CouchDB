# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/content/drive/MyDrive/movies_metadata.csv")
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult  ... vote_count
# 0  False  ...     5415.0
# 1  False  ...     2413.0
# 2  False  ...       92.0
# 3  False  ...       34.0
# 4  False  ...      173.0
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
data['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
data['popularity'] = pd.to_numeric(data['popularity'],errors = 'coerce')
data['popularity']
# Out:
# 0        21.946943
# 1        17.015539
# 2        11.712900
# 3         3.859495
# 4         8.387519
#            ...
# 45461     0.072051
# 45462     0.178241
# 45463     0.903007
# 45464     0.003503
# 45465     0.163015
# Name: popularity, Length: 45466, dtype: float64

# %%
data['budget'] = pd.to_numeric(data['budget'],errors = 'coerce')
data['budget']
# Out:
# 0        30000000.0
# 1        65000000.0
# 2               0.0
# 3        16000000.0
# 4               0.0
#             ...
# 45461           0.0
# 45462           0.0
# 45463           0.0
# 45464           0.0
# 45465           0.0
# Name: budget, Length: 45466, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats

data['vote_average'].hist()
plt.xticks(rotation = 90)
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# Хистограм за колоната **vote-average**.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats
from numpy.random import randn

x = 50; 
nbins = 10;

data['revenue'].hist()
plt.xticks(rotation = 90)
# Out:
# (array([-5.0e+08,  0.0e+00,  5.0e+08,  1.0e+09,  1.5e+09,  2.0e+09,
#          2.5e+09,  3.0e+09]), <a list of 8 Text major ticklabel objects>)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure()
data.plot.scatter(x= 'popularity', y = 'vote_count', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# На хистограмот гледаме силно, позитивно и линеарна врска помеѓу ентитетите.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure()
data.plot.scatter(x= 'vote_average', y = 'budget', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# Силна, позитивна и нелинеарна врска

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

# %%
sns.catplot(x="vote_average", y="budget", data=data)

# %%
import missingno as msno
msno.bar(data)

# %%
msno.dendrogram(data)

# %%
msno.heatmap(data)

# %%
null_vrednosti=data.isnull().sum()
vo_proenti=100*data.isnull().sum()/len(data)
null_tabela=pd.concat([null_vrednosti,vo_proenti],axis=1)
null_tabela.columns=["Br. vrednosti sto nedostasuvaat","Vo procenti"]
null_tabela
# Out:
#                        Br. vrednosti sto nedostasuvaat  Vo procenti
# adult                                                0     0.000000
# belongs_to_collection                            40972    90.115691
# budget                                               3     0.006598
# genres                                               0     0.000000
# homepage                                         37684    82.883913
# id                                                   0     0.000000
# imdb_id                                             17     0.037391
# original_language                                   11     0.024194
# original_title                                       0     0.000000
# overview                                           954     2.098271
# popularity                                           6     0.013197
# poster_path                                        386     0.848986
# production_companies                                 3     0.006598
# ...

# %%
data.drop(['belongs_to_collection','homepage','tagline'], inplace=True, axis=1)
data
# Out:
#        adult      budget  ... vote_average vote_count
# 0      False  30000000.0  ...          7.7     5415.0
# 1      False  65000000.0  ...          6.9     2413.0
# 2      False         0.0  ...          6.5       92.0
# 3      False  16000000.0  ...          6.1       34.0
# 4      False         0.0  ...          5.7      173.0
# ...      ...         ...  ...          ...        ...
# 45461  False         0.0  ...          4.0        1.0
# 45462  False         0.0  ...          9.0        3.0
# 45463  False         0.0  ...          3.8        6.0
# 45464  False         0.0  ...          0.0        0.0
# 45465  False         0.0  ...          0.0        0.0
#
# [45466 rows x 21 columns]

# %%
is_NaN = data.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = data[row_has_NaN]

print(rows_with_NaN)
# Out:
#        adult      budget  ... vote_average vote_count
# 32     False         0.0  ...          6.8        4.0
# 189    False         0.0  ...          5.3        2.0
# 300    False  22000000.0  ...          6.4        7.0
# 554    False         0.0  ...          0.0        1.0
# 634    False         0.0  ...          4.0        1.0
# ...      ...         ...  ...          ...        ...
# 45399  False    750000.0  ...          6.0        4.0
# 45410  False         0.0  ...          6.0        1.0
# 45431  False         0.0  ...          0.0        0.0
# 45442  False         0.0  ...          5.0        3.0
# 45461  False         0.0  ...          4.0        1.0
#
# [1418 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import pandas
from pandas.plotting import scatter_matrix
names = data.columns
scatter_matrix(data, figsize=(10, 15))
plt.show()

# %%
corr=data.corr()

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Correlation matrix")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_d149e3ca_5f61_11ec_a479_0242ac1c0002 th {
#           font-size: 7pt;
#     }    #T_d149e3ca_5f61_11ec_a479_0242ac1c0002 td {
#           padding: 0em 0em;
#     }    #T_d149e3ca_5f61_11ec_a479_0242ac1c0002 th:hover {
#           font-size: 12pt;
#     }    #T_d149e3ca_5f61_11ec_a479_0242ac1c0002 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row0_col0,#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row1_col1,#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row2_col2,#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row3_col3,#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row4_col4,#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row5_col5{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_d149e3ca_5f61_11ec_a479_0242ac1c0002row0_col1{
#             background-color:  #edcfd5;
#             color:  #000000;
# ...

# %%
data['release_date'].map(type)
# Out:
# 0          <class 'str'>
# 1          <class 'str'>
# 2          <class 'str'>
# 3          <class 'str'>
# 4          <class 'str'>
#               ...
# 45461    <class 'float'>
# 45462      <class 'str'>
# 45463      <class 'str'>
# 45464      <class 'str'>
# 45465      <class 'str'>
# Name: release_date, Length: 45466, dtype: object

# %%
data.to_csv('nosql.csv', encoding='utf-8')
